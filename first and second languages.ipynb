# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("C:\\Users\\dazvi\\Downloads\\List of languages by total number of speakers.csv")
data.head()
#as we can see there is a unamed column
# Out:
#    Unnamed: 0                                           Language  \
# 0           0                    English(excl. creole languages)
# 1           1  Mandarin Chinese(incl. Standard Chinese, but e...
# 2           2                                  Hindi(excl. Urdu)
# 3           3                                            Spanish
# 4           4                                             French
#
#           Family      Branch First-language(L1) speakers  \
# 0  Indo-European    Germanic               372.9 million
# 1   Sino-Tibetan     Sinitic               929.0 million
# 2  Indo-European  Indo-Aryan               343.9 million
# 3  Indo-European     Romance               474.7 million
# 4  Indo-European     Romance                79.9 million
#
#   Second-language(L2) speakers Total speakers(L1+L2)
# 0             1.080 billion[5]         1.452 billion
# 1             198.7 million[6]         1.118 billion
# 2             258.3 million[7]         602.2 million
# ...

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)
data.head()
# Out:
#                                             Language         Family  \
# 0                    English(excl. creole languages)  Indo-European
# 1  Mandarin Chinese(incl. Standard Chinese, but e...   Sino-Tibetan
# 2                                  Hindi(excl. Urdu)  Indo-European
# 3                                            Spanish  Indo-European
# 4                                             French  Indo-European
#
#        Branch First-language(L1) speakers Second-language(L2) speakers  \
# 0    Germanic               372.9 million             1.080 billion[5]
# 1     Sinitic               929.0 million             198.7 million[6]
# 2  Indo-Aryan               343.9 million             258.3 million[7]
# 3     Romance               474.7 million              73.6 million[8]
# 4     Romance                79.9 million             194.2 million[9]
#
#   Total speakers(L1+L2)
# 0         1.452 billion
# 1         1.118 billion
# 2         602.2 million
# 3         548.3 million
# ...

# %%
# Lets view shape of the data
data.shape
# Out:
# (45, 6)

# %%
# Lets find if there is any duplicate value in the dataset
data.duplicated().any()
