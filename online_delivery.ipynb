# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\dazvi\OneDrive\Desktop\cognifyz internship\Dataset .csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#find count of hotels which provides online delivery
online_delivery = df['Has Online delivery'].value_counts()
online_delivery
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
#find total restaurants
total_restaurants = online_delivery.sum()
total_restaurants
# Out:
# 9551

# %%
#find online_delivery_percentage
online_delivery_percentage = (online_delivery['Yes'] / total_restaurants) * 100
online_delivery_percentage
# Out:
# 25.662234321013504

# %%
# find data of restaurant has online delivery
df[df['Has Online delivery']=='Yes']
# Out:
#       Restaurant ID                   Restaurant Name  Country Code  \
# 565         5704255            Famous Dave's Barbecue           214
# 566         5701978                    Pizza Di Rocco           214
# 571         5700052  Cho Gao - Crowne Plaza Abu Dhabi           214
# 572         5702418                            Gazebo           214
# 573         5700386   Sangeetha Vegetarian Restaurant           214
# ...             ...                               ...           ...
# 9166          11371                           Chili's             1
# 9168       18292672                        Blue Water             1
# 9170        6507967                   Tales & Spirits             1
# 9171        6506206           18 Degrees Resto Lounge             1
# 9194          96814                    Saffron Mantra             1
#
#               City                                            Address  \
# 565      Abu Dhabi  Near The One, Level 3, Abu Dhabi Mall, Tourist...
# ...

# %%
# find data of restaurant doesn't has online delivery
df[df['Has Online delivery']=='No']
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
# Compare the average ratings of restaurants with and without online delivery
avg_rating_online = df[df['Has Online delivery'] == 'Yes']['Aggregate rating'].mean()
avg_rating_online
# Out:
# 3.2488372093023257

# %%
avg_rating_no_online = df[df['Has Online delivery'] == 'No']['Aggregate rating'].mean()
avg_rating_no_online
# Out:
# 2.465295774647887

# %%
'''hence restaurant with online delivery has high ratings'''

# %%
'''
Step 1: Imported Libraries
Step 2: read CSV file
Step 3: found count of hotels which provides online delivery
Step 4: found total restaurants
Step 5: found online_delivery_percentage
Step 6: found data of restaurant has online delivery
Step 7: found data of restaurant doesn't has online delivery
Step 8: Compare the average ratings of restaurants with and without online delivery
'''
